# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyCTF6PEc6H43Pq5vEEfpns0cfgwwavniIk'
channel_id  = 'UCh4V6e39E0Qx6lrvVzrK9sw'

youtube = build('youtube','v3',developerKey=api_key)

# %% [markdown]
# ## Function to get playlistId from Channel

# %%
def get_channel_details(youtube,channel_id):
    
    request = youtube.channels().list(
        part = 'snippet,contentDetails,statistics',
        id= channel_id)
    response = request.execute()
    
    PlayListID = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    return PlayListID

# %%
PlayListID = get_channel_details(youtube,channel_id)

# %%
PlayListID
# Out:
# 'UUh4V6e39E0Qx6lrvVzrK9sw'

# %% [markdown]
# ## Function to get VideoID

# %%
def get_video_ids(youtube,PlayListID):
    
    request = youtube.playlistItems().list(
                part = 'contentDetails',
                playlistId=PlayListID,
                maxResults = 10)
    response = request.execute()
    
    video_ids =[]
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    return video_ids

# %%
video_ids = get_video_ids(youtube,PlayListID)
video_ids
# Out:
# ['64_1sRtAfYA',
#  '6GU8wyBiYPQ',
#  '2MSFIG_CGQg',
#  'HGXYCcgNl8Y',
#  'QOd2d2vsgqs',
#  'ANbC3o6tnww',
#  'JnBhX_t63K4',
#  'M_fZvu_oAmM',
#  '6T4AzcpoCi8',
#  'uSwGFUpEOzw']

# %% [markdown]
# ## Function to get video Details

# %%
def get_video_details(youtube,video_ids):
    request = youtube.videos().list(
                part = 'snippet,statistics',
                id = ','.join(video_ids))
    response = request.execute()
    all_video_data = []
    for video in response['items']:
        video_data = dict(Title = video['snippet']['title'],
                          Date_of_Publish = video['snippet']['publishedAt'],
                          Views = video['statistics']['viewCount'],
                          Likes = video['statistics']['likeCount'],
                        DisLikes = video['statistics']['dislikeCount'])
        all_video_data.append(video_data)
        
    return all_video_data

# %%
Video_details = get_video_details(youtube,video_ids)

# %%
Video_Data = pd.DataFrame(Video_details)
Video_Data
# Out:
#                                                Title       Date_of_Publish  \
# 0  TANHA KYUN I Official Music Video I Kushal Man...  2021-08-12T07:06:39Z
# 1  Gustakhiya - Mayank Maurya l Official l TBS Mu...  2021-03-09T06:30:17Z
# 2  Rihaa Cover Song | Maadhyam Feat. Rajveer Sing...  2020-10-04T11:00:13Z
# 3  Kahin Door Jab Din Dhal Jaye I Maadhyam I Pian...  2020-02-14T08:33:31Z
# 4  Maadhyam I Ghar Se Nikalte Hi I Udit Narayan I...  2019-11-02T06:31:35Z
# 5  Sach Keh Raha Hai Deewana | Maadhyam | Rehna H...  2019-07-22T10:30:48Z
# 6  Sajna Ve I Maadhyam I Cover Song I Vishal Mish...  2019-06-04T15:13:46Z
# 7  Na Tum Jano Na Hum by Maadhyam l Kaho Na Pyar ...  2019-04-23T06:06:18Z
# 8  Main Taare (cover) - Maadhyam | New Song | Sal...  2019-03-19T06:17:24Z
# 9  Gazab Ka Hai Din - Official Video  I Modern Re...  2019-03-01T07:43:29Z
#
#       Views    Likes DisLikes
# 0    148637     2163       28
# 1    252016     5278      306
# 2     62290     3033      104
# ...

# %%
Video_Data['Video_ID'] = video_ids
Video_Data
# Out:
#                                                Title       Date_of_Publish  \
# 0  TANHA KYUN I Official Music Video I Kushal Man...  2021-08-12T07:06:39Z
# 1  Gustakhiya - Mayank Maurya l Official l TBS Mu...  2021-03-09T06:30:17Z
# 2  Rihaa Cover Song | Maadhyam Feat. Rajveer Sing...  2020-10-04T11:00:13Z
# 3  Kahin Door Jab Din Dhal Jaye I Maadhyam I Pian...  2020-02-14T08:33:31Z
# 4  Maadhyam I Ghar Se Nikalte Hi I Udit Narayan I...  2019-11-02T06:31:35Z
# 5  Sach Keh Raha Hai Deewana | Maadhyam | Rehna H...  2019-07-22T10:30:48Z
# 6  Sajna Ve I Maadhyam I Cover Song I Vishal Mish...  2019-06-04T15:13:46Z
# 7  Na Tum Jano Na Hum by Maadhyam l Kaho Na Pyar ...  2019-04-23T06:06:18Z
# 8  Main Taare (cover) - Maadhyam | New Song | Sal...  2019-03-19T06:17:24Z
# 9  Gazab Ka Hai Din - Official Video  I Modern Re...  2019-03-01T07:43:29Z
#
#       Views    Likes DisLikes     Video_ID
# 0    148637     2163       28  64_1sRtAfYA
# 1    252016     5278      306  6GU8wyBiYPQ
# ...

# %%
Video_Data['Views'] = pd.to_numeric(Video_Data['Views'])
Video_Data['Likes'] = pd.to_numeric(Video_Data['Likes'])
Video_Data['DisLikes'] = pd.to_numeric(Video_Data['DisLikes'])

# %%
Video_Data.dtypes
# Out:
# Title              object
# Date_of_Publish    object
# Views               int64
# Likes               int64
# DisLikes            int64
# Video_ID           object
# dtype: object

# %%
Video_Data.to_csv('YoutubeAPIScrap.csv')

# %%
data = pd.read_csv(r'C:\Users\Akshay\Desktop\Internshala\YoutubeAPIScrap.csv',index_col=0)
data
# Out:
#                                                Title       Date_of_Publish  \
# 0  TANHA KYUN I Official Music Video I Kushal Man...  2021-08-12T07:06:39Z
# 1  Gustakhiya - Mayank Maurya l Official l TBS Mu...  2021-03-09T06:30:17Z
# 2  Rihaa Cover Song | Maadhyam Feat. Rajveer Sing...  2020-10-04T11:00:13Z
# 3  Kahin Door Jab Din Dhal Jaye I Maadhyam I Pian...  2020-02-14T08:33:31Z
# 4  Maadhyam I Ghar Se Nikalte Hi I Udit Narayan I...  2019-11-02T06:31:35Z
# 5  Sach Keh Raha Hai Deewana | Maadhyam | Rehna H...  2019-07-22T10:30:48Z
# 6  Sajna Ve I Maadhyam I Cover Song I Vishal Mish...  2019-06-04T15:13:46Z
# 7  Na Tum Jano Na Hum by Maadhyam l Kaho Na Pyar ...  2019-04-23T06:06:18Z
# 8  Main Taare (cover) - Maadhyam | New Song | Sal...  2019-03-19T06:17:24Z
# 9  Gazab Ka Hai Din - Official Video  I Modern Re...  2019-03-01T07:43:29Z
#
#       Views    Likes  DisLikes     Video_ID
# 0    148637     2163        28  64_1sRtAfYA
# 1    252016     5278       306  6GU8wyBiYPQ
# ...
